# %% [markdown]
# # Activité 3

# %% [markdown]
# Ecrire une fonction `nombre_de_noeuds(arbre)` qui prend en argument un objet de type `Noeud` et qui renvoie le **nombre de noeuds** contenus dans `arbre` (à gauche ou à droite)!
#
# Exemple  :
#
#     >>> nombre_de_noeuds(Noeud( Noeud(None,'A',None), 'racine', Noeud(None,'B',None) ))
#     3
#     >>> nombre_de_noeuds(Noeud(None,'A',None) )
#     1

# %%
class Noeud:
    def __init__(self, g, v, d):
        self.gauche = g
        self.valeur = v        
        self.droit  = d

def nombre_de_noeuds(arbre):
    if arbre is None : 
        return 0
    # else :
    cpt = 1
    cpt += nombre_de_noeuds(arbre.droit)
    cpt += nombre_de_noeuds(arbre.gauche)
    return cpt

# %%
nombre_de_noeuds(Noeud( Noeud(None,'A',None), 'racine', Noeud(None,'B',None) ))
# Out:
# 3

# %%
nombre_de_noeuds(arbre2)
# Out:
# 5

# %%
nombre_de_noeuds(arbre1)
# Out:
# 4

# %% [markdown]
# ### solution en trois lignes de code

# %%
def nombre_de_noeuds(arbre):
    if arbre is None : 
        return 0
    return 1 + nombre_de_noeuds(arbre.droit) + nombre_de_noeuds(arbre.gauche)

# %% [markdown]
# pour mémoire...

# %%
def nombre_de_noeuds(arbre):
    return 0 if arbre is None else 1 + nombre_de_noeuds(arbre.droit) + nombre_de_noeuds(arbre.gauche)
