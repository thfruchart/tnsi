# %% [markdown]
# # rappels sur les listes

# %% [markdown]
# ## méthode index

# %%
L = [10,20,30,40,50]
L.index(40)

# %%
L.index(1789)

# %% [markdown]
# ## slicing

# %%
L = [10,20,30,40,50,60,70]

# %%
L[2:4]

# %%
L[3:]

# %%
L[:3]
