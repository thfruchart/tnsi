# %% [markdown]
# ## Plusieurs parcours sur un même arbre binaire

# %% [markdown]
# #### utilisation du module `binarytree` pour créer un arbre binaire aléatoire

# %%
from binarytree import tree
my_tree = tree(height=2, is_perfect=True, letters=True)
my_tree

# %% [markdown]
# ## PARCOURS
#
# 1. Recopier sur votre brouillon, l'arbre ci-dessus
# 2. pour chacun des parcours suivants,
#    * noter sur votre brouillon le résultat du parcours
#    * vérifier en exécutant la cellule
#    * remarque : par défaut, on explorera le sous-arbre **gauche** AVANT le sous-arbre **droit**.

# %% [markdown]
# ### parcours préfixe

# %%
my_tree.preorder

# %% [markdown]
# ### parcours infixe

# %%
my_tree.inorder

# %% [markdown]
# ### parcours postfixe

# %%
my_tree.postorder

# %% [markdown]
# ###  parcours en largeur

# %%
my_tree.values
