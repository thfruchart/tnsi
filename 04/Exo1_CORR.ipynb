# %%
class Maillon:
    def __init__(self, val, suiv=None):
        self.valeur = val
        self.suivant = suiv
    
    def __str__(self):
        if self is None:
            return ''
        if self.suivant is None:
            return str(self.valeur)
        return str(self.valeur) + '-' + str(self.suivant)

lst = Maillon(10,Maillon(20))
print(lst)
# Out:
# 10-20

# %%
lst.suivant = Maillon(15, lst.suivant )
print(lst)
# Out:
# 10-15-20

# %%
lst.suivant.suivant.suivant = Maillon(25)
print(lst)
# Out:
# 10-15-20-25

# %%
def ajoute_a_la_fin(lst, v):
    while lst.suivant is not None : 
        lst = lst.suivant
    lst.suivant = Maillon(v)

# %%
ajoute_a_la_fin(lst, 100)
print(lst)

# %% [markdown]
# Visualiser sur [PythonTutor](https://pythontutor.com/render.html#code=class%20Maillon%3A%0A%20%20%20%20def%20__init__%28self,%20val,%20suiv%3DNone%29%3A%0A%20%20%20%20%20%20%20%20self.valeur%20%3D%20val%0A%20%20%20%20%20%20%20%20self.suivant%20%3D%20suiv%0A%0Alst%20%3D%20Maillon%2810,Maillon%2820%29%29%0Alst.suivant%20%3D%20Maillon%2815,%20lst.suivant%20%29%0Alst.suivant.suivant.suivant%20%3D%20Maillon%2825%29%0A%0Adef%20ajoute_a_la_fin%28lst,%20v%29%3A%0A%20%20%20%20while%20lst.suivant%20is%20not%20None%20%3A%20%0A%20%20%20%20%20%20%20%20lst%20%3D%20lst.suivant%0A%20%20%20%20lst.suivant%20%3D%20Maillon%28v%29%0Aajoute_a_la_fin%28lst,%20100%29&cumulative=false&curInstr=35&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false)

# %% [markdown]
# # BONUS
# transformer la fonction en méthode

# %%
class Maillon:
    def __init__(self, val, suiv=None):
        self.valeur = val
        self.suivant = suiv
    
    def __str__(self):
        if self is None:
            return ''
        if self.suivant is None:
            return str(self.valeur)
        return str(self.valeur) + '-' + str(self.suivant)

    def ajoute_a_la_fin(self, v):
        while self.suivant is not None : 
            self = self.suivant
        self.suivant = Maillon(v)

lst = Maillon(10,Maillon(20))
print(lst)
# Out:
# 10-20

# %%
lst.ajoute_a_la_fin(40)
print(lst)
# Out:
# 10-20-40
